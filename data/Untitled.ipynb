# %%
import json

# %%
json_data = open("summary_frequency.json")

# %%
data = json.load(json_data)

# %%
data
# Out:
# [{'2012': 245.4947173,
#   '2013': 301.3220345,
#   '2014': 264.9524468,
#   '2015': 305.3226892,
#   '2016': 253.8597225,
#   'community_area': 1,
#   'name': 'Rogers Park'},
#  {'2012': 262.9896305,
#   '2013': 371.6883045,
#   '2014': 409.357538,
#   '2015': 455.9228267,
#   '2016': 315.3929554,
#   'community_area': 2,
#   'name': 'West Ridge'},
#  {'2012': 257.9752315,
#   '2013': 253.1847699,
#   '2014': 281.9275398,
#   '2015': 378.2690465,
#   '2016': 317.2350165,
#   'community_area': 3,
#   'name': 'Uptown'},
#  {'2012': 357.7849239,
#   '2013': 596.3082065,
#   '2014': 764.4392677,
#   '2015': 802.4206821,
#   '2016': 956.3720153,
#   'community_area': 4,
#   'name': 'Lincoln Square'},
#  {'2012': 503.028211,
#   '2013': 726.4568362,
#   '2014': 773.8412778,
#   '2015': 948.002636,
#   '2016': 1032.102175,
#   'community_area': 5,
#   'name': 'North Center'},
#  {'2012': 231.6463208,
#   '2013': 395.2611055,
#   '2014': 422.1770092,
#   '2015': 412.8518142,
# ...

# %%
output = []

# %%
for d in data:
    point = {"community_area": d['community_area'],
            "name": d['name'],
            "frequency": []}
    for i in ["2012", "2013", "2014", "2015", "2016"]:
        point["frequency"].append({"year": int(i), "count": d[i]})
        
    output.append(point)

# %%
output
# Out:
# [{'community_area': 1,
#   'frequency': [{'count': 245.4947173, 'year': 2012},
#    {'count': 301.3220345, 'year': 2013},
#    {'count': 264.9524468, 'year': 2014},
#    {'count': 305.3226892, 'year': 2015},
#    {'count': 253.8597225, 'year': 2016}],
#   'name': 'Rogers Park'},
#  {'community_area': 2,
#   'frequency': [{'count': 262.9896305, 'year': 2012},
#    {'count': 371.6883045, 'year': 2013},
#    {'count': 409.357538, 'year': 2014},
#    {'count': 455.9228267, 'year': 2015},
#    {'count': 315.3929554, 'year': 2016}],
#   'name': 'West Ridge'},
#  {'community_area': 3,
#   'frequency': [{'count': 257.9752315, 'year': 2012},
#    {'count': 253.1847699, 'year': 2013},
#    {'count': 281.9275398, 'year': 2014},
#    {'count': 378.2690465, 'year': 2015},
#    {'count': 317.2350165, 'year': 2016}],
#   'name': 'Uptown'},
#  {'community_area': 4,
#   'frequency': [{'count': 357.7849239, 'year': 2012},
#    {'count': 596.3082065, 'year': 2013},
# ...
